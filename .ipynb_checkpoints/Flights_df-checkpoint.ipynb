# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
flights = pd.read_csv("../Flight-Data---Project-2-/info/data/flights.csv")
airports = pd.read_csv("../Flight-Data---Project-2-/info/data/airports.csv")
airlines = pd.read_csv("../Flight-Data---Project-2-/info/data/airports.csv")

# %%
flights.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1  1.0          4.0      AS           98.0      N407AS
# 1  2015      1  1.0          4.0      AA         2336.0      N3KUAA
# 2  2015      1  1.0          4.0      US          840.0      N171US
# 3  2015      1  1.0          4.0      AA          258.0      N3HYAA
# 4  2015      1  1.0          4.0      AS          135.0      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  ARRIVAL_TIME  \
# 0            ANC                 SEA                  5.0  ...         408.0
# 1            LAX                 PBI                 10.0  ...         741.0
# 2            SFO                 CLT                 20.0  ...         811.0
# 3            LAX                 MIA                 20.0  ...         756.0
# 4            SEA                 ANC                 25.0  ...         259.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# ...

# %%
airports.head()
# Out:
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport     Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport       Albany    GA     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236  -75.44040
# 1  32.41132  -99.68190
# 2  35.04022 -106.60919
# 3  45.44906  -98.42183
# 4  31.53552  -84.19447

# %%
airlines.head()
# Out:
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport     Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport       Albany    GA     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236  -75.44040
# 1  32.41132  -99.68190
# 2  35.04022 -106.60919
# 3  45.44906  -98.42183
# 4  31.53552  -84.19447

# %%
df1 = flights[['DAY_OF_WEEK','DEPARTURE_DELAY']]
df1.head()
# Out:
#    DAY_OF_WEEK  DEPARTURE_DELAY
# 0          4.0            -11.0
# 1          4.0             -8.0
# 2          4.0             -2.0
# 3          4.0             -5.0
# 4          4.0             -1.0

# %%
#Relationship between days of the week and departure delay 
#This shows there are most delays on Sundays and Mondays - this coule be 
#due to the influx of people trying to get back home from weekend travels which may put pressure on the airlines 


ax = sns.barplot(x="DAY_OF_WEEK", y="DEPARTURE_DELAY", data=df1, palette="husl", ci=None)

plt.title("DEPARTURE DELAY vs DAY OF THE WEEK")

plt.savefig("DEP DELAYS vs DAYS OF THE WEEK.png")

# %%
flights['SCHEDULED_DEPARTURE'] = pd.to_datetime(flights['SCHEDULED_DEPARTURE'])

# %%
flights['DATE'] = pd.to_datetime(flights[['YEAR','MONTH', 'DAY']])
flights.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1  1.0          4.0      AS           98.0      N407AS
# 1  2015      1  1.0          4.0      AA         2336.0      N3KUAA
# 2  2015      1  1.0          4.0      US          840.0      N171US
# 3  2015      1  1.0          4.0      AA          258.0      N3HYAA
# 4  2015      1  1.0          4.0      AS          135.0      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT           SCHEDULED_DEPARTURE  ...  \
# 0            ANC                 SEA 1970-01-01 00:00:00.000000005  ...
# 1            LAX                 PBI 1970-01-01 00:00:00.000000010  ...
# 2            SFO                 CLT 1970-01-01 00:00:00.000000020  ...
# 3            LAX                 MIA 1970-01-01 00:00:00.000000020  ...
# 4            SEA                 ANC 1970-01-01 00:00:00.000000025  ...
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# ...

# %%
# Function that convert the 'HHMM' string to datetime.time
def format_heure(chaine):
    if pd.isnull(chaine):
        return np.nan
    else:
        if chaine == 2400: chaine = 0
        chaine = "{0:04d}".format(int(chaine))
        heure = datetime.time(int(chaine[0:2]), int(chaine[2:4]))
        return heure
#_____________________________________________________________________
# Function that combines a date and time to produce a datetime.datetime
def combine_date_heure(x):
    if pd.isnull(x[0]) or pd.isnull(x[1]):
        return np.nan
    else:
        return datetime.datetime.combine(x[0],x[1])
#_______________________________________________________________________________
# Function that combine two columns of the dataframe to create a datetime format
def create_flight_time(flights, col):
    liste = []
    for index, cols in flights[['DATE', col]].iterrows():
        if pd.isnull(cols[1]):
            liste.append(np.nan)
        elif float(cols[1]) == 2400:
            cols[0] += datetime.timedelta(days=1)
            cols[1] = datetime.time(0,0)
            liste.append(combine_date_heure(cols))
        else:
            cols[1] = format_heure(cols[1])
            liste.append(combine_date_heure(cols))
    return pd.Series(liste)

# %%
flights.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1  1.0          4.0      AS           98.0      N407AS
# 1  2015      1  1.0          4.0      AA         2336.0      N3KUAA
# 2  2015      1  1.0          4.0      US          840.0      N171US
# 3  2015      1  1.0          4.0      AA          258.0      N3HYAA
# 4  2015      1  1.0          4.0      AS          135.0      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT           SCHEDULED_DEPARTURE  ...  \
# 0            ANC                 SEA 1970-01-01 00:00:00.000000005  ...
# 1            LAX                 PBI 1970-01-01 00:00:00.000000010  ...
# 2            SFO                 CLT 1970-01-01 00:00:00.000000020  ...
# 3            LAX                 MIA 1970-01-01 00:00:00.000000020  ...
# 4            SEA                 ANC 1970-01-01 00:00:00.000000025  ...
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# ...

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 665180 entries, 0 to 665179
# Data columns (total 32 columns):
# YEAR                   665180 non-null int64
# MONTH                  665180 non-null int64
# DAY                    665179 non-null float64
# DAY_OF_WEEK            665179 non-null float64
# AIRLINE                665179 non-null object
# FLIGHT_NUMBER          665179 non-null float64
# TAIL_NUMBER            660835 non-null object
# ORIGIN_AIRPORT         665179 non-null object
# DESTINATION_AIRPORT    665179 non-null object
# SCHEDULED_DEPARTURE    665179 non-null datetime64[ns]
# DEPARTURE_TIME         645329 non-null float64
# DEPARTURE_DELAY        645329 non-null float64
# TAXI_OUT               644989 non-null float64
# WHEELS_OFF             644989 non-null float64
# SCHEDULED_TIME         665177 non-null float64
# ELAPSED_TIME           643432 non-null float64
# AIR_TIME               643432 non-null float64
# DISTANCE               665179 non-null float64
# ...

# %%
flights['SCHEDULED_DEPARTURE'] = create_flight_time(flights, 'SCHEDULED_DEPARTURE')
flights['DEPARTURE_TIME'] = flights['DEPARTURE_TIME'].apply(format_heure)
flights['SCHEDULED_ARRIVAL'] = flights['SCHEDULED_ARRIVAL'].apply(format_heure)
flights['ARRIVAL_TIME'] = flights['ARRIVAL_TIME'].apply(format_heure)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-38f9c3573c9b> in <module>
# ----> 1 flights['SCHEDULED_DEPARTURE'] = create_flight_time(flights, 'SCHEDULED_DEPARTURE')
#       2 flights['DEPARTURE_TIME'] = flights['DEPARTURE_TIME'].apply(format_heure)
#       3 flights['SCHEDULED_ARRIVAL'] = flights['SCHEDULED_ARRIVAL'].apply(format_heure)
#       4 flights['ARRIVAL_TIME'] = flights['ARRIVAL_TIME'].apply(format_heure)
#       5
#
# <ipython-input-56-93763f55e184> in create_flight_time(flights, col)
#      22         if pd.isnull(cols[1]):
#      23             liste.append(np.nan)
# ---> 24         elif float(cols[1]) == 2400:
#      25             cols[0] += datetime.timedelta(days=1)
#      26             cols[1] = datetime.time(0,0)
#
# TypeError: float() argument must be a string or a number, not 'Timestamp'

# %%
flights.loc[:5, ['SCHEDULED_DEPARTURE', 'SCHEDULED_ARRIVAL', 'DEPARTURE_TIME',
             'ARRIVAL_TIME', 'DEPARTURE_DELAY', 'ARRIVAL_DELAY']]
# Out:
#             SCHEDULED_DEPARTURE  SCHEDULED_ARRIVAL  DEPARTURE_TIME  \
# 0 1970-01-01 00:00:00.000000005              430.0          2354.0
# 1 1970-01-01 00:00:00.000000010              750.0             2.0
# 2 1970-01-01 00:00:00.000000020              806.0            18.0
# 3 1970-01-01 00:00:00.000000020              805.0            15.0
# 4 1970-01-01 00:00:00.000000025              320.0            24.0
# 5 1970-01-01 00:00:00.000000025              602.0            20.0
#
#    ARRIVAL_TIME  DEPARTURE_DELAY  ARRIVAL_DELAY
# 0         408.0            -11.0          -22.0
# 1         741.0             -8.0           -9.0
# 2         811.0             -2.0            5.0
# 3         756.0             -5.0           -9.0
# 4         259.0             -1.0          -21.0
# 5         610.0             -5.0            8.0

# %%
df['dep_hour'] = df['SCHEDULED_DEPARTURE'].apply(lambda x:x.time().hour)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-10355d616a46> in <module>
# ----> 1 df['dep_hour'] = df['SCHEDULED_DEPARTURE'].apply(lambda x:x.time().hour)
#
# NameError: name 'df' is not defined
