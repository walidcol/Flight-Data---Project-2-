# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
file = "/Users/Aziz/Desktop/Flight-Data---Project-2-/info/data/flights.csv"

# %%
df = pd.read_csv(file)
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1  1.0          4.0      AS           98.0      N407AS
# 1  2015      1  1.0          4.0      AA         2336.0      N3KUAA
# 2  2015      1  1.0          4.0      US          840.0      N171US
# 3  2015      1  1.0          4.0      AA          258.0      N3HYAA
# 4  2015      1  1.0          4.0      AS          135.0      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  DEPARTURE_TIME  \
# 0            ANC                 SEA                  5.0          2354.0
# 1            LAX                 PBI                 10.0             2.0
# 2            SFO                 CLT                 20.0            18.0
# 3            LAX                 MIA                 20.0            15.0
# 4            SEA                 ANC                 25.0            24.0
#
#    DEPARTURE_DELAY  TAXI_OUT  WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME  \
# ...

# %%
d_count = df["DESTINATION_AIRPORT"].value_counts()

# %%
d_count
# Out:
# ATL    41995
# ORD    33392
# DFW    32765
# LAX    24462
# DEN    24022
# IAH    18985
# PHX    18536
# SFO    18159
# LAS    16419
# MCO    14167
# LGA    13671
# DTW    13514
# CLT    13188
# MSP    12782
# BOS    12646
# EWR    12388
# SLC    12189
# JFK    11929
# SEA    11917
# FLL    10120
# BWI     9744
# DCA     9584
# MDW     9558
# MIA     9420
# SAN     8576
# TPA     8435
# PHL     8194
# DAL     7329
# HOU     6602
# BNA     5799
#        ...
# CIU       81
# EWN       80
# GGG       77
# BRD       77
# PUB       76
# CDC       76
# APN       76
# PLN       76
# HYS       76
# CNY       76
# PIB       75
# ESC       75
# INL       75
# LWS       75
# VEL       75
# STC       70
# HOB       70
# DVL       69
# MMH       51
# IAG       44
# GUM       44
# ADQ       43
# PBG       43
# MQT       38
# ILG       36
# OTH       25
# UST       23
# BGM       21
# PPG       14
# ADK       13
# Name: DESTINATION_AIRPORT, Length: 313, dtype: int64

# %%
d_count = pd.DataFrame(d_count)
d_count
# Out:
#                                       DESTINATION_AIRPORT
# ATL                                                 41995
# ORD                                                 33392
# DFW                                                 32765
# LAX                                                 24462
# DEN                                                 24022
# IAH                                                 18985
# PHX                                                 18536
# SFO                                                 18159
# LAS                                                 16419
# MCO                                                 14167
# LGA                                                 13671
# DTW                                                 13514
# CLT                                                 13188
# MSP                                                 12782
# BOS                                                 12646
# ...

# %%
d_count.to_json("flight_destination.json", index=True, header=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-55dda9ad905f> in <module>
# ----> 1 d_count.to_json("flight_destination.json", index=True, header=True)
#
# TypeError: to_json() got an unexpected keyword argument 'header'

# %%
new_df = df.groupby(["AIRLINE"])["MONTH"].count()

# %%
new_df = pd.DataFrame(new_df)
new_df = new_df.reset_index()
# Preview DataFrame
new_df
# Out:
#    AIRLINE   MONTH
# 0       AA   62165
# 1       AS   18810
# 2       B6   30433
# 3       DL   91863
# 4       EV   70445
# 5       F9    9530
# 6       HA    9091
# 7       MQ   42398
# 8       NK   12372
# 9       OO   67983
# 10      UA   54595
# 11      US   47317
# 12      VX    6695
# 13      WN  141482

# %%
new_file = "/Users/Aziz/Desktop/Flight-Data---Project-2-/data-1575424962745.csv"

# %%
df = pd.read_csv(new_file)
pd.set_option('display.max_columns', None)
df
# Out:
#    airline  day_of_week  number_of_flights
# 0       AA            1               8761
# 1       AS            1               2599
# 2       B6            1               4316
# 3       DL            1              13669
# 4       EV            1              10431
# 5       F9            1               1417
# 6       HA            1               1247
# 7       MQ            1               6056
# 8       NK            1               1699
# 9       OO            1               9845
# 10      UA            1               8077
# 11      US            1               6565
# 12      VX            1                978
# 13      WN            1              20373
# 14      AA            2               8388
# 15      AS            2               2471
# 16      B6            2               4037
# 17      DL            2              12481
# 18      EV            2               9983
# 19      F9            2               1271
# 20      HA            2               1206
# ...

# %%
df["day_of_week"]=df["day_of_week"].replace(1, "Monday")
df["day_of_week"]=df["day_of_week"].replace(2, "Tuesday")
df["day_of_week"]=df["day_of_week"].replace(3, "Wednesday")
df["day_of_week"]=df["day_of_week"].replace(4, "Thursday")
df["day_of_week"]=df["day_of_week"].replace(5, "Friday")
df["day_of_week"]=df["day_of_week"].replace(6, "Saturday")
df["day_of_week"]=df["day_of_week"].replace(7, "Sunday")

# %%
df
# Out:
#    airline day_of_week  number_of_flights
# 0       AA      Monday               8761
# 1       AS      Monday               2599
# 2       B6      Monday               4316
# 3       DL      Monday              13669
# 4       EV      Monday              10431
# 5       F9      Monday               1417
# 6       HA      Monday               1247
# 7       MQ      Monday               6056
# 8       NK      Monday               1699
# 9       OO      Monday               9845
# 10      UA      Monday               8077
# 11      US      Monday               6565
# 12      VX      Monday                978
# 13      WN      Monday              20373
# 14      AA     Tuesday               8388
# 15      AS     Tuesday               2471
# 16      B6     Tuesday               4037
# 17      DL     Tuesday              12481
# 18      EV     Tuesday               9983
# 19      F9     Tuesday               1271
# 20      HA     Tuesday               1206
# ...

# %%
df.to_csv("flight_weekday.csv", index=False)
